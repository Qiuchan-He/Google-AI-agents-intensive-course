# %% [markdown]
# ##### Copyright 2025 Google LLC.

# %% [markdown]
# # 🚀 Memory Management - Part 1 - Sessions
#
# **Welcome to Day 3 of the Kaggle 5-day Agents course!**
#
# In this notebook, you'll learn:
#
# - ✅ What sessions are and how to use them in your agent
# - ✅ How to build *stateful* agents with sessions and events
# - ✅ How to persist sessions in a database
# - ✅ Context management practices such as context compaction
# - ✅ Best practices for sharing session State

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### 1.3: Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### 1.4: Helper functions
#
# Helper function that manages a complete conversation session, handling session
# creation/retrieval, query processing, and response streaming. It supports
# both single queries and multiple queries in sequence.
#
# Example:
#
# ```
# >>> await run_session(runner, "What is the capital of France?", "geography-session")
# >>> await run_session(runner, ["Hello!", "What's my name?"], "user-intro-session")
# ```

# %%
# Define helper functions that will be reused throughout the notebook
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### 1.5: Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %% [markdown]
# ---
# ## 🤹 Section 2: Session Management
#
# ### 2.1 The Problem
#
# At their core, Large Language Models are **inherently stateless**. Their awareness is confined to the information you provide in a single API call. This means an agent without proper context management will react to the current prompt without considering any previous history.
#
# **❓ Why does this matter?** Imagine trying to have a meaningful conversation with someone who forgets everything you've said after each sentence. That's the challenge we face with raw LLMs!
#
# In ADK, we use `Sessions` for **short term memory management** and `Memory` for **long term memory.** In the next notebook, you'll focus on `Memory`.

# %% [markdown]
# ### 2.2 What is a Session?
#
# #### **📦 Session**
#
# A session is a container for conversations. It encapsulates the conversation history in a chronological manner and also records all tool interactions and responses for a **single, continuous conversation**. A session is tied to a user and agent; it is not shared with other users. Similarly, a session history for an Agent is not shared with other Agents.
#
# In ADK, a **Session** is comprised of two key components `Events` and `State`:
#
# **📝 Session.Events**:
#
# > While a session is a container for conversations, `Events` are the building blocks of a conversation.
# >
# > Example of Events:
# > - *User Input*: A message from the user (text, audio, image, etc.)
# > - *Agent Response*: The agent's reply to the user
# > - *Tool Call*: The agent's decision to use an external tool or API
# > - *Tool Output*: The data returned from a tool call, which the agent uses to continue its reasoning
#
#
# **{} Session.State**:
#
# > `session.state` is the Agent's scratchpad, where it stores and updates dynamic details needed during the conversation. Think of it as a global `{key, value}` pair storage which is available to all subagents and tools.

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/session-state-and-events.png" width="320" alt="Session state and events">
#
# <!-- ```mermaid
# graph TD
#     subgraph A["Agentic Application"];
#         subgraph U["User"]
#             subgraph S1["Session"]
#                 D1["Session.Events"]
#                 D2["Session.State"]
#             end
#         end
#     end
# ``` -->

# %% [markdown]
# ### 2.3 How to manage sessions?
#
# An agentic application can have multiple users and each user may have multiple sessions with the application.
# To manage these sessions and events, ADK offers a **Session Manager** and **Runner**.
#
# 1. **`SessionService`**: The storage layer
#    - Manages creation, storage, and retrieval of session data
#    - Different implementations for different needs (memory, database, cloud)
#
# 2. **`Runner`**: The orchestration layer
#    - Manages the flow of information between user and agent
#    - Automatically maintains conversation history
#    - Handles the Context Engineering behind the scenes
#
# Think of it like this:
#
# - **Session** = A notebook 📓
# - **Events** = Individual entries in a single page 📝
# - **SessionService** = The filing cabinet storing notebooks 🗄️
# - **Runner** = The assistant managing the conversation 🤖

# %% [markdown]
# ### 2.4 Implementing Our First Stateful Agent
#
# Let's build our first stateful agent, that can remember and have constructive conversations.
#
# ADK offers different types of sessions suitable for different needs. As a start, we'll start with a simple Session Management option (`InMemorySessionService`):

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"


# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %% [markdown]
# ### 2.5 Testing Our Stateful Agent
#
# Now let's see the magic of sessions in action!

# %%
# Run a conversation with two queries in the same session
# Notice: Both queries are part of the SAME session, so context is maintained
await run_session(
    runner,
    [
        "Hi, I am Sam! What is the capital of United States?",
        "Hello! What is my name?",  # This time, the agent should remember!
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Hi, I am Sam! What is the capital of United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam!

# %% [markdown]
# 🎉 **Success!** The agent remembered your name because both queries were part of the same session. The Runner automatically maintained the conversation history.
#
# But there's a catch: `InMemorySessionService` is temporary. **Once the application stops, all conversation history is lost.**

# %% [markdown]
# ### 🛑 (Optional) 2.6 Testing Agent's forgetfulness
#
# > To verify that the agent forgets the conversation, **restart the kernel**. Then, **run ALL the previous cells in this notebook EXCEPT the `run_session` in 2.5.**
# >
# > Now run the cell below. You'll see that the agent doesn't remember anything from the previous conversation.

# %%
# Run this cell after restarting the kernel. All this history will be gone...
await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)  # Note, we are using same session name
# Out:
#  ### Session: stateful-agentic-session
#
# User > What did I ask you about earlier?
# gemini-2.5-flash-lite >  You asked me about the capital of the United States.
#
# User > And remind me, what's my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### The Problem
#
# Session information is not persistent (i.e., meaningful conversations are lost). While this is advantageous in testing environments, **in the real world, a user should be able to refer from past and resume conversations.** To achieve this, we must persist information.

# %% [markdown]
# ---
# ## 📈 Section 3: Persistent Sessions with `DatabaseSessionService`
#
# While `InMemorySessionService` is great for prototyping, real-world applications need conversations to survive restarts, crashes, and deployments. Let's level up to persistent storage!
#
# ### 3.1 Choosing the Right SessionService
#
# ADK provides different SessionService implementations for different needs:
#
# | Service | Use Case | Persistence | Best For |
# |---------|----------|-------------|----------|
# | **InMemorySessionService** | Development & Testing | ❌ Lost on restart | Quick prototypes |
# | **DatabaseSessionService** | Self-managed apps | ✅ Survives restarts | Small to medium apps |
# | **Agent Engine Sessions** | Production on GCP | ✅ Fully managed | Enterprise scale |

# %% [markdown]
# ### 3.2 Implementing Persistent Sessions
#
# Let's upgrade to `DatabaseSessionService` using SQLite. This gives us persistence without needing a separate database server for this demo.
#
# Let's create a `chatbot_agent` capable of having a conversation with the user.

# %%
# Step 1: Create the same agent (notice we use LlmAgent this time)
chatbot_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot with persistent memory",
)

# Step 2: Switch to DatabaseSessionService
# SQLite database will be created automatically
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Step 3: Create a new runner with persistent storage
runner = Runner(agent=chatbot_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %% [markdown]
# ### 3.3 Test Run 1: Verifying Persistence
#
# In this first test run, we'll start a new conversation with the session ID `test-db-session-01`. We will first introduce our name as 'Sam' and then ask a question. In the second turn, we will ask the agent for our name.
#
# Since we are using `DatabaseSessionService`, the agent should remember the name.
#
# After the conversation, we'll inspect the `my_agent_data.db` SQLite database directly to see how the conversation `events` (the user queries and model responses) are stored.

# %%
await run_session(
    runner,
    ["Hi, I am Sam! What is the capital of the United States?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > Hi, I am Sam! What is the capital of the United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### 🛑 (Optional) 3.4 Test Run 2: Resuming a Conversation
#
# > ‼️ Now, let's repeat the test again, but this time, **let's stop this Kaggle Notebook's kernel and restart it again.**
# >
# > 1. Run all the previous cells in the notebook, **EXCEPT** the previous Section 3.3 (`run_session` cell).
# >
# > 2. Now, run the below cell with the **same session ID** (`test-db-session-01`).
#
# We will ask a new question and then ask for our name again. **Because the session is loaded from the database, the agent should still remember** that our name is 'Sam' from the first test run. This demonstrates the power of persistent sessions.

# %%
await run_session(
    runner,
    ["What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of India?
# gemini-2.5-flash-lite >  The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### 3.5 Let's verify that the session data is isolated
#
# As mentioned earlier, a session is private conversation between an Agent and a User (i.e., two sessions do not share information). Let's run our `run_session` with a different session name `test-db-session-02` to confirm this.

# %%
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)  # Note, we are using new session name
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I do not have access to your personal information, including your name. I am a large language model, trained by Google.

# %% [markdown]
# ### 3.6 How are the events stored in the Database?
#
# Since we are using a sqlite DB to store information, let's have a quick peek to see how information is stored.

# %%
import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()
# Out:
# ['app_name', 'session_id', 'author', 'content']
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hi Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, including your name. I am a large language model, trained by Google."}], "role": "model"}')

# %% [markdown]
# ---
# ## ⏳ Section 4: Context Compaction
#
# As you can see, all the events are stored in full in the session Database, and this quickly adds up. For a long, complex task, this list of events can become very large, leading to slower performance and higher costs.
#
# But what if we could automatically summarize the past? Let's use ADK's **Context Compaction** feature to see **how to automatically reduce the context that's stored in the Session.**

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/context-compaction.png" width="1400" alt="Context compaction">

# %% [markdown]
# ### 4.1 Create an App for the agent
#
# To enable this feature, let's use the same `chatbot_agent` we created in Section 3.2.
#
# The first step is to create an object called `App`. We'll give it a name and pass in our chatbot_agent.
#
# We'll also create a new config to do the Context Compaction. This **`EventsCompactionConfig`** defines two key variables:
#
# - **compaction_interval**: Asks the Runner to compact the history after every `n` conversations
# - **overlap_size**: Defines the number of previous conversations to retain for overlap
#
# We'll then provide this app to the Runner.

# %%
# Re-define our app with Events Compaction enabled
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chatbot_agent,
    # This is the new part!
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  # Trigger compaction every 3 invocations
        overlap_size=1,  # Keep 1 previous turn for context
    ),
)

db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Create a new runner for our upgraded app
research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)


print("✅ Research App upgraded with Events Compaction!")
# Out:
# ✅ Research App upgraded with Events Compaction!
# /tmp/ipykernel_48/3773147741.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %% [markdown]
# ### 4.2 Running the Demo
#
# Now, let's have a conversation that is long enough to trigger the compaction. When you run the cell below, the output will look like a normal conversation. However, because we configured our `App`, a compaction process will run silently in the background after the 3rd invocation.
#
# In the next step, we'll prove that it happened.

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)

# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)

# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)

# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  The field of AI in healthcare is rapidly evolving, with new developments and research emerging constantly. Here's a summary of some of the latest and most significant trends and news:
#
# **Key Areas of Advancement and Focus:**
#
# *   **Drug Discovery and Development:**
#     *   **Accelerated timelines:** AI is dramatically speeding up the identification of potential drug candidates, predicting their efficacy, and optimizing clinical trial design. Companies are using AI to analyze vast datasets of biological and chemical information.
#     *   **Personalized medicine:** AI is helping to identify which drugs will be most effective for individual patients based on their genetic makeup, lifestyle, and medical history.
#     *   **Novel target identification:** AI is uncovering new biological targets for diseases that were previously unknown or difficult to study.
#
# *   **Medical Imaging and Diagnostics:**
#     *   **Improved accuracy and speed:** AI algorithms are becoming increasingly adept at analyzing medical images (X-rays, CT scans, MRIs, pathology slides) to detect anomalies, tumors, and diseases with higher accuracy and at earlier stages than human radiologists alone.
#     *   **Early disease detection:** AI is being deployed to screen for conditions like diabetic retinopathy, breast cancer, and skin cancer, often in settings where specialized expertise is scarce.
#     *   **Radiology workflow optimization:** AI tools are assisting radiologists by prioritizing urgent cases, automating measurements, and reducing the burden of repetitive tasks.
#
# *   **Predictive Analytics and Early Intervention:**
#     *   **Identifying at-risk patients:** AI models can predict which patients are most likely to develop certain conditions (e.g., sepsis, heart failure, readmission after surgery) allowing for proactive interventions.
#     *   **Personalized treatment plans:** AI helps tailor treatment strategies based on predicted patient responses and risk factors.
#     *   **Population health management:** AI analyzes large datasets to identify health trends, predict outbreaks, and allocate resources more effectively.
#
# *   **AI-Powered Assistants and Robotics:**
#     *   **Clinical decision support:** AI tools are providing physicians with evidence-based recommendations, flagging potential drug interactions, and suggesting diagnostic pathways.
#     *   **Robotic surgery:** AI is enhancing surgical robots, offering greater precision, minimally invasive procedures, and improved patient outcomes.
#     *   **Virtual health assistants:** AI-powered chatbots and virtual assistants are being used for patient triage, appointment scheduling, medication reminders, and answering common health questions.
#
# *   **Administrative Efficiency and Operations:**
#     *   **Streamlining workflows:** AI is automating tasks like medical coding, billing, claims processing, and appointment scheduling, freeing up healthcare professionals' time.
#     *   **Improving hospital management:** AI can optimize resource allocation, predict patient flow, and reduce wait times.
#
# **Recent Developments and Trends:**
#
# *   **Generative AI in Healthcare:**
#     *   **Content creation:** Generative AI is being explored for drafting clinical notes, generating patient summaries, and even creating synthetic medical data for training AI models.
#     *   **Medical education and training:** Simulating patient scenarios and creating interactive learning materials.
#     *   **Drug design:** Generating novel molecular structures with desired properties.
# *   **Focus on Explainability and Trust:** As AI becomes more integrated, there's a growing emphasis on making AI decisions understandable (explainable AI or XAI) and building trust among clinicians and patients.
# *   **Regulatory Scrutiny:** Regulatory bodies like the FDA are actively developing frameworks for evaluating and approving AI-driven medical devices and software, ensuring safety and efficacy.
# *   **Data Privacy and Security:** With the increasing use of sensitive patient data, robust data privacy and security measures are paramount, and AI is also being used to enhance these aspects.
# *   **Integration Challenges:** A significant ongoing challenge is the seamless integration of AI tools into existing healthcare IT infrastructure and clinical workflows.
# *   **AI for Mental Health:** AI is being used to develop new tools for diagnosing and treating mental health conditions, including chatbots for therapy and predictive models for identifying individuals at risk of suicide.
#
# **Where to Find Latest News:**
#
# To stay truly up-to-date, I recommend following these sources:
#
# *   **Reputable Healthcare News Outlets:** Fierce Biotech, STAT News, Healthcare IT News, MedTech Dive, NEJM Journal Watch, JAMA.
# *   **AI and Technology Publications:** TechCrunch, MIT Technology Review, VentureBeat (AI section).
# *   **Academic Journals:** Nature Medicine, The Lancet Digital Health, NPJ Digital Medicine, Journal of Medical Internet Research.
# *   **Major Tech Companies' Health Divisions:** Google Health, Microsoft Healthcare, IBM Watson Health (though its structure has changed).
# *   **Leading Research Institutions and Hospitals:** Look for news releases from organizations like Mayo Clinic, Cleveland Clinic, Johns Hopkins, and major universities with strong medical and AI programs.
#
# The field is incredibly dynamic, so continuous learning is key!
#
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, there are **very significant and exciting new developments** in drug discovery, largely driven by the advancement and application of AI and other cutting-edge technologies. Here's a breakdown of the latest trends and breakthroughs:
#
# **1. AI and Machine Learning Dominance:**
#
# *   **Accelerated Target Identification:** AI algorithms are sifting through massive datasets (genomic, proteomic, clinical) to identify novel biological targets for diseases far faster than traditional methods. They can uncover subtle patterns and correlations that humans might miss.
# *   **De Novo Drug Design:** AI models, particularly generative AI, are now capable of designing entirely new molecular structures from scratch that are predicted to bind to specific targets and possess desired therapeutic properties. This is a paradigm shift from simply screening existing compound libraries.
# *   **Predictive Modeling for Efficacy and Toxicity:** AI is improving the prediction of how effective a drug candidate will be and its potential side effects early in the discovery process, reducing the number of compounds that fail in later, expensive stages.
# *   **Optimizing Clinical Trial Design:** AI is being used to identify ideal patient populations for clinical trials, predict patient responses, and potentially shorten trial durations, making the overall development process more efficient.
# *   **Repurposing Existing Drugs:** AI can identify new therapeutic uses for existing drugs by analyzing their mechanisms of action and comparing them to disease pathways.
#
# **2. Advances in Specific AI Techniques:**
#
# *   **Generative AI (like large language models and diffusion models):** These are proving particularly powerful for designing novel molecules with specific properties, predicting protein structures, and even generating synthetic biological data for training AI models.
# *   **Graph Neural Networks (GNNs):** GNNs are excellent at modeling molecular structures and their interactions, making them highly effective for predicting drug-target binding and molecular properties.
# *   **Reinforcement Learning:** Used to optimize drug discovery processes, such as designing molecules iteratively to achieve desired characteristics.
#
# **3. Focus on Specific Disease Areas and Modalities:**
#
# *   **Oncology:** AI is making strides in identifying personalized cancer therapies, predicting drug resistance, and designing novel oncology drugs.
# *   **Neurodegenerative Diseases:** AI is helping to understand the complex mechanisms of diseases like Alzheimer's and Parkinson's, leading to the identification of new therapeutic targets.
# *   **Rare Diseases:** AI's ability to analyze limited datasets and find patterns is proving invaluable for accelerating research into rare genetic disorders.
# *   **RNA Therapeutics:** AI is being used to design more effective mRNA vaccines and therapies, as well as to develop novel RNA-based drugs for a range of conditions.
# *   **Peptide Therapeutics:** AI is aiding in the design of novel peptide drugs, which offer potential advantages in terms of specificity and reduced side effects.
#
# **4. New Technological Platforms:**
#
# *   **High-Throughput Screening (HTS) with AI Integration:** Combining automated screening of vast compound libraries with AI analysis to rapidly identify promising hits.
# *   **Organ-on-a-Chip and Microfluidics:** These technologies allow for more realistic testing of drug candidates in controlled environments, providing better data for AI models.
# *   **CRISPR and Gene Editing:** While not directly drug discovery, CRISPR technology is enabling researchers to better understand gene function and validate drug targets, which feeds into AI-driven discovery.
#
# **5. Notable Company Initiatives and Partnerships:**
#
# Many pharmaceutical giants are investing heavily in AI and partnering with specialized AI drug discovery companies. Examples include:
#
# *   **Insilico Medicine:** Known for its AI-driven drug discovery platform and rapid progression of candidates into clinical trials.
# *   **Exscientia:** Uses AI to design novel molecules and has several drugs in clinical development.
# *   **Recursion Pharmaceuticals:** Leverages AI and automation to map cellular biology and discover new drug candidates.
# *   **Big Pharma's internal AI efforts:** Companies like Pfizer, Novartis, Merck, and AstraZeneca are building significant in-house AI capabilities for drug discovery.
#
# **Challenges and the Road Ahead:**
#
# Despite the incredible progress, challenges remain:
#
# *   **Data Quality and Accessibility:** The effectiveness of AI heavily relies on high-quality, comprehensive, and well-annotated biological data.
# *   **Validation and Experimental Verification:** AI-designed drugs still need rigorous experimental validation and clinical testing.
# *   **Integration into Existing Workflows:** Seamlessly integrating AI tools into traditional R&D pipelines can be complex.
# *   **Regulatory Pathways:** Adapting regulatory processes for AI-discovered and designed drugs is an ongoing effort.
#
# In summary, drug discovery is undergoing a revolution fueled by AI and advanced technologies. We are seeing a future where drugs are designed faster, more precisely, and with a higher probability of success, ultimately leading to new treatments for unmet medical needs.
#
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're referring to the second major development I highlighted: **Advances in Specific AI Techniques**. This is a crucial area because it's the *how* behind the breakthroughs in drug discovery. It's about the specific types of AI algorithms and models that are enabling these new capabilities.
#
# Let's dive deeper into the most impactful ones:
#
# **1. Generative AI (e.g., Large Language Models - LLMs, Diffusion Models):**
#
# *   **What it is:** Generative AI models are designed to create new content. In the context of drug discovery, this "content" can be novel molecular structures, protein sequences, or even synthetic biological data.
#     *   **LLMs:** Originally popularized for text generation (like myself!), LLMs are being adapted to understand and generate sequences – be it DNA, RNA, or even SMILES strings (a way to represent chemical molecules). They can "learn" the rules of chemistry and biology to propose new drug-like molecules.
#     *   **Diffusion Models:** These models excel at generating complex data, like images. In drug discovery, they are being used to generate 3D molecular structures with specific shapes and properties, which is critical for how a drug interacts with its target.
# *   **How it's applied in Drug Discovery:**
#     *   **De Novo Molecule Design:** This is the most prominent application. Instead of screening millions of existing compounds, generative AI can design entirely new molecules tailored to a specific disease target. Think of it as creating a custom-fit key for a biological lock.
#     *   **Protein Engineering:** Designing novel proteins or optimizing existing ones for therapeutic purposes.
#     *   **Synthetic Data Generation:** Creating realistic, artificial biological data for training other AI models, especially useful when real-world data is scarce or proprietary.
#     *   **Drug Combination Prediction:** Suggesting optimal combinations of existing drugs for enhanced therapeutic effects.
#
# **2. Graph Neural Networks (GNNs):**
#
# *   **What it is:** GNNs are a type of deep learning specifically designed to work with data represented as graphs. In chemistry, molecules are naturally represented as graphs where atoms are nodes and bonds are edges.
# *   **How it's applied in Drug Discovery:**
#     *   **Predicting Molecular Properties:** GNNs can accurately predict a wide range of properties for a given molecule, such as its solubility, toxicity, binding affinity to a target, and even its synthetic accessibility.
#     *   **Drug-Target Interaction Prediction:** By modeling both the drug molecule and the target protein (also representable as a graph or learned as embeddings), GNNs can predict how strongly they will interact.
#     *   **Drug Discovery Property Optimization:** GNNs can be used in conjunction with generative models to guide the design process, ensuring that the generated molecules have desirable properties.
#     *   **Analyzing Biological Networks:** Beyond molecules, GNNs can analyze complex biological networks (e.g., protein-protein interaction networks) to identify key nodes (potential drug targets) or pathways.
#
# **3. Reinforcement Learning (RL):**
#
# *   **What it is:** RL is a type of machine learning where an "agent" learns to make decisions by performing actions in an environment to maximize a cumulative reward. It's like training a robot to play a game.
# *   **How it's applied in Drug Discovery:**
#     *   **Automated Molecule Generation:** RL can be used to "train" an AI to generate molecules step-by-step, where each step (adding an atom or bond) contributes to a reward signal (e.g., better binding affinity or desired chemical properties). The AI learns through trial and error to optimize its molecule-building strategy.
#     *   **Optimizing Synthesis Pathways:** RL can be used to design the most efficient and cost-effective chemical synthesis routes for a target molecule.
#     *   **Adaptive Experimental Design:** Guiding laboratory experiments to yield the most informative data for further AI model refinement.
#
# **Why these advances are significant:**
#
# *   **Moving Beyond Screening:** These techniques allow us to *design* molecules with desired properties rather than just searching through existing ones. This is a fundamental shift.
# *   **Increased Speed and Efficiency:** By making more accurate predictions early on, these AI techniques drastically reduce the time and cost associated with identifying promising drug candidates.
# *   **Tackling Complex Diseases:** They provide powerful tools to understand and target diseases with complex biological mechanisms, where traditional approaches might have failed.
# *   **Unlocking New Chemical Space:** Generative AI can explore vast regions of chemical possibility that have never been synthesized or tested before.
#
# The synergy between these AI techniques is also key. Often, a generative model will propose candidate molecules, and a GNN will evaluate their properties, with RL potentially guiding the iterative refinement of both. This combination of methods is accelerating the pace of innovation in drug discovery dramatically.
#
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# gemini-2.5-flash-lite >  The landscape of companies involved in AI-driven drug discovery is dynamic and diverse, spanning established pharmaceutical giants, dedicated AI biotech startups, and major tech companies with healthcare divisions.
#
# Here's a breakdown of the key players, categorized for clarity:
#
# **1. Dedicated AI Drug Discovery Startups (Often leading the charge with novel platforms):**
#
# *   **Insilico Medicine:** One of the most prominent. They use generative AI for target identification, novel molecule design, and have advanced several AI-discovered drugs into clinical trials rapidly.
# *   **Exscientia:** Known for its AI platform that designs novel molecules. They have multiple drugs in clinical trials in partnership with major pharmaceutical companies.
# *   **Recursion Pharmaceuticals:** Leverages AI and automation to map cellular biology and discover new drug candidates. They focus on identifying new uses for existing drugs and discovering novel therapies.
# *   **Atomwise:** Uses deep learning for small molecule drug discovery, specifically for predicting binding interactions.
# *   **Schrödinger:** While not solely an AI company, they are a leader in physics-based computational chemistry and have increasingly integrated AI and machine learning into their platform for drug discovery.
# *   **BenevolentAI:** Uses its AI platform to analyze vast amounts of biomedical data to identify new drug targets and understand disease mechanisms.
# *   **Relay Therapeutics:** Focuses on understanding protein motion with advanced experimental and computational techniques, increasingly incorporating AI.
# *   **DeepMind (Google/Alphabet subsidiary):** While not a drug developer itself, their AI for protein folding (AlphaFold) has been a monumental development that significantly aids drug discovery by providing accurate protein structures. They are also reportedly exploring therapeutic development internally.
# *   **Cerebras Systems:** Develops specialized hardware (AI chips) for AI workloads, which are crucial for accelerating complex drug discovery computations.
#
# **2. Major Pharmaceutical Companies (Integrating AI into their R&D):**
#
# These companies are investing heavily in building their own AI capabilities and forming strategic partnerships.
#
# *   **Pfizer:** Actively using AI across its R&D pipeline, including drug discovery, clinical trial optimization, and manufacturing.
# *   **Novartis:** Has a strong focus on AI and data science in drug discovery and development, with internal teams and collaborations.
# *   **AstraZeneca:** Employs AI for target identification, drug design, and clinical trial management.
# *   **Merck (MSD):** Utilizing AI for various stages of drug discovery and development.
# *   **Johnson & Johnson:** Investing in AI and machine learning for target identification and drug design.
# *   **Roche/Genentech:** Leveraging AI for drug discovery and personalized medicine.
# *   **Sanofi:** Exploring AI for drug target identification and molecule generation.
# *   **Eli Lilly and Company:** Incorporating AI into its drug discovery and development processes.
#
# **3. Tech Giants with Healthcare/AI Focus:**
#
# These companies are developing foundational AI technologies and platforms that are being adopted by the life sciences industry.
#
# *   **Google (Alphabet):** Beyond DeepMind's AlphaFold, Google Cloud offers AI/ML tools and infrastructure that support drug discovery. Verily (another Alphabet company) is also involved in health tech and data analysis.
# *   **Microsoft:** Provides cloud-based AI and machine learning services (Azure AI) that are used by many biotech and pharma companies for their R&D.
# *   **Amazon (AWS):** Offers cloud computing and AI/ML services that are instrumental for handling the massive datasets involved in drug discovery.
#
# **4. Companies Focused on Specific Modalities or Technologies:**
#
# *   **Moderna/BioNTech:** While primarily known for mRNA vaccines, AI plays a role in their platform for designing mRNA sequences and optimizing manufacturing.
# *   **Companies focused on computational biology and simulation:** These companies provide the underlying tools and expertise that are often integrated with AI.
#
# **Key Trends in Company Involvement:**
#
# *   **Partnerships and Acquisitions:** Established pharma companies are increasingly partnering with or acquiring AI-native biotech firms to gain access to their technology and expertise.
# *   **In-house AI Centers of Excellence:** Many large pharma companies are building significant internal AI capabilities and hiring data scientists and AI researchers.
# *   **Focus on Generative AI:** The recent surge in generative AI has led to a proliferation of startups and new initiatives focused on this area for molecule design.
# *   **Hardware for AI:** Companies developing specialized AI chips (like Cerebras) are also critical enablers.
#
# This is not an exhaustive list, as the field is constantly evolving with new players emerging. However, these are some of the most influential companies shaping the future of AI-driven drug discovery.

# %% [markdown]
# ### 4.3 Verifying Compaction in the Session History
#
# The conversation above looks normal, but the history has been changed behind the scenes. How can we prove it?
#
# We can inspect the `events` list from our session. The compaction process **doesn't delete old events; it replaces them with a single, new `Event` that contains the summary.** Let's find it.

# %%
# Get the final session state
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='dd9e1e85-5e9c-41c0-ade9-dc6bc1a8a221' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1763135879.901098, 'end_timestamp': 1763135890.877108, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user asked about the latest news in AI in healthcare. The AI agent provided a comprehensive overview, covering key areas like drug discovery, medical imaging, predictive analytics, AI-powered assistants, and administrative efficiency. It also highlighted recent trends such as generative AI, the focus on explainability, regulatory scrutiny, data privacy, integration challenges, and AI for mental health. The agent then provided a list of reputable sources for staying updated.\n\nThe user then inquired specifically about new developments in drug discovery. The AI agent detailed how AI and machine learning are revolutionizing this field by accelerating target identification, enabling de novo drug design, improving predictions for efficacy and toxicity, optimizing clinical trials, and facilitating drug repurposing. It also mentioned specific AI techniques being used and their applications.\n\nFinally, the user asked for more information about the second development discussed (Advances in Specific AI Techniques). The AI agent elaborated on three key techniques:\n\n1.  **Generative AI (LLMs and Diffusion Models):** Explained how these models create new content, such as novel molecular structures and protein sequences, and are applied to de novo molecule design, protein engineering, and synthetic data generation.\n2.  **Graph Neural Networks (GNNs):** Described their ability to work with graph-structured data, like molecules, and their applications in predicting molecular properties, drug-target interactions, and analyzing biological networks.\n3.  **Reinforcement Learning (RL):** Explained its agent-based learning approach and its use in automated molecule generation and optimizing synthesis pathways.\n\nThe conversation highlighted the significant impact of these AI techniques on accelerating drug discovery by enabling design over screening, increasing efficiency, and tackling complex diseases. No unresolved questions or tasks remain from this interaction.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='d0650f3e-3aa0-4ff1-8425-4ec9c512c3f4' timestamp=1763135898.678653

# %% [markdown]
# ### 4.4 What you've accomplished: Automatic Context Management
#
# You just found the proof! The presence of that special summary `Event` in your session's history is the tangible result of the compaction process.
#
# **Let's recap what you just witnessed:**
#
# 1.  **Silent Operation**: You ran a standard conversation, and from the outside, nothing seemed different.
# 2.  **Background Compaction**: Because you configured the `App` with `EventsCompactionConfig`, the ADK `Runner` automatically monitored the conversation length. Once the threshold was met, it triggered the summarization process in the background.
# 3.  **Verified Result**: By inspecting the session's events, you found the summary that the LLM generated. This summary now replaces the older, more verbose turns in the agent's active context.
#
# **For all future turns in this conversation, the agent will be given this concise summary instead of the full history.** This saves costs, improves performance, and helps the agent stay focused on what's most important.

# %% [markdown]
# ### 4.5 More Context Engineering options in ADK
#
# #### 👉 Custom Compaction
# In this example, we used ADK's default summarizer. For more advanced use cases, you can provide your own by defining a custom `SlidingWindowCompactor` and passing it to the config. This allows you to control the summarization prompt or even use a different, specialized LLM for the task. You can read more about it in the [official documentation](https://google.github.io/adk-docs/context/compaction/).
#
# #### 👉 Context Caching
# ADK also provides **Context Caching** to help reduce the token size of the static instructions that are fed to the LLM by caching the request data. Read more about it [here](https://google.github.io/adk-docs/context/caching/).

# %% [markdown]
# ### The Problem
#
# While we can do Context Compaction and use a database to resume a session, we face new challenges now. In some cases, **we have key information or preferences that we want to share across other sessions.**
#
# In these scenarios, instead of sharing the entire session history, transferring information from a few key variables can improve the session experience. Let's see how to do it!

# %% [markdown]
# ---
# ## 🤝 Section 5: Working with Session State
#
# ### 5.1 Creating custom tools for Session state management
#
# Let's explore how to manually manage session state through custom tools. In this example, we'll identify a **transferable characteristic**, like a user's name and their country, and create tools to capture and save it.
#
# **Why This Example?**
#
# The username is a perfect example of information that:
#
# - Is introduced once but referenced multiple times
# - Should persist throughout a conversation
# - Represents a user-specific characteristic that enhances personalization
#
# Here, for demo purposes, we'll create two tools that can store and retrieve user name and country from the Session State. **Note that all tools have access to the `ToolContext` object.** You don't have to create separate tools for each piece of information you want to share.

# %%
# Define scope levels for state keys (following best practices)
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")


# This demonstrates how tools can write to session state using tool_context.
# The 'user:' prefix indicates this is user-specific data.
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}


# This demonstrates how tools can read from session state.
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}


print("✅ Tools created.")
# Out:
# ✅ Tools created.

# %% [markdown]
# **Key Concepts:**
# - Tools can access `tool_context.state` to read/write session state
# - Use descriptive key prefixes (`user:`, `app:`, `temp:`) for organization
# - State persists across conversation turns within the same session

# %% [markdown]
# ### 5.2 Creating an Agent with Session State Tools
#
# Now let's create a new agent that has access to our session state management tools:

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool. 
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

print("✅ Agent with session state tools initialized!")
# Out:
# ✅ Agent with session state tools initialized!

# %% [markdown]
# ### 5.3 Testing Session State in Action
#
# Let's test how the agent uses session state to remember information across conversation turns:

# %%
# Test conversation demonstrating session state
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Sam. I'm from Poland.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great, thank you for asking. I can't recall your name just yet. Can you please tell me what it is?
#
#
# User > My name is Sam. I'm from Poland.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Hi Sam! It's a pleasure to meet you. I'll remember that you're from Poland.
#
#
# User > What is my name? Which country am I from?
# gemini-2.5-flash-lite >  Hello Sam! You are from Poland.

# %% [markdown]
# ### 5.4 Inspecting Session State
#
# Let's directly inspect the session state to see what's stored:

# %%
# Retrieve the session and inspect its state
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {'user:name': 'Sam', 'user:country': 'Poland'}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %% [markdown]
# ### 5.5 Session State Isolation
#
# As we've already seen, an important characteristic of session state is that it's isolated per session. Let's demonstrate this by starting a new session:

# %%
# Start a completely new session - the agent won't know our name
await run_session(
    runner,
    ["Hi there, how are you doing today? What is my name?"],
    "new-isolated-session",
)

# Expected: The agent won't know the name because this is a different session
# Out:
#  ### Session: new-isolated-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing well, thank you for asking. I can't recall your name at the moment. Would you like to share it with me?

# %% [markdown]
# ### 5.6 Cross-Session State Sharing
#
# While sessions are isolated by default, you might notice something interesting. Let's check the state of our new session (`new-isolated-session`):

# %%
# Check the state of the new session
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="new-isolated-session"
)

print("New Session State:")
print(session.state)

# Note: Depending on implementation, you might see shared state here.
# This is where the distinction between session-specific and user-specific state becomes important.
# Out:
# New Session State:
# {'user:name': 'Sam', 'user:country': 'Poland'}

# %% [markdown]
# ---
#
# ## 🧹 Cleanup

# %%
# Clean up any existing database to start fresh (if Notebook is restarted)
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")
# Out:
# ✅ Cleaned up old database files

# %% [markdown]
# ---
# ## 📊 Summary
#
# 🎉 Congratulations! You've learned the fundamentals of building stateful AI agents:
#
# - ✅ **Context Engineering** - You understand how to assemble context for LLMs using Context Compaction
# - ✅ **Sessions & Events** - You can maintain conversation history across multiple turns
# - ✅ **Persistent Storage** - You know how to make conversations survive restarts
# - ✅ **Session State** - You can track structured data during conversations
# - ✅ **Manual State Management** - You've experienced both the power and limitations of manual approaches
# - ✅ **Production Considerations** - You're ready to handle real-world challenges

# %% [markdown]
# ---
#
# ## ✅ Congratulations! You did it 🎉
#
# **ℹ️ Note: No submission required!**
#
# This notebook is for your hands-on practice and learning only. You **do not** need to submit it anywhere to complete the course.
#
# ### 📚 Learn More
#
# Refer to the following documentation to learn more:
#
# - [ADK Documentation](https://google.github.io/adk-docs/)
# - [ADK Sessions](https://google.github.io/adk-docs/)
# - [ADK Session-State](https://medium.com/google-cloud/2-minute-adk-manage-context-efficiently-with-artifacts-6fcc6683d274)
# - [ADK Session Compaction](https://google.github.io/adk-docs/context/compaction/#define-compactor)
#
# ### 🎯 Next Steps - Long Term Memory Systems (Part 2)
#
# #### Why do we need memory?
# In this notebook, we manually identified a couple characteristic (username and country) and built tools to manage it. But real conversations involve hundreds of such characteristics:
# - User preferences and habits
# - Past interactions and their outcomes
# - Domain knowledge and expertise levels
# - Communication styles and patterns
# - Contextual relationships between topics
#
# **The Memory System in ADK automates this entire process**, making it a valuable asset for building truly Context-Aware Agents that can accommodate any user's current and future needs.
#
# In the next notebook (Part 2: Memory Management), you'll learn how to:
# - Enable automatic memory extraction from conversations
# - Build agents that learn and adapt over time
# - Create truly personalized experiences at scale
# - Manage long-term knowledge across sessions
#
# Ready to transform your manual state management into an intelligent, automated Memory system? Let's continue to Part 2!

# %% [markdown]
# ---
#
# | Authors |
# | --- |
# | [Sampath M](https://www.linkedin.com/in/msampathkumar/) |
